# %% [markdown]
# <a href="https://colab.research.google.com/github/ttutto/2021_PNUAC_AIData/blob/main/07_codelab3_bs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🏷️ **웹 동작원리**
#
#
# ---
# <img src ='https://drive.google.com/uc?export=view&id=1amZ78fUnfp3o5Q1XVKDG3eAAzKaYlPrp'>
#
# ---

# %% [markdown]
# # Beautiful Soup 모듈
# + HTML 및 XML 문서 를 구문 분석하기 위한 Python 패키지
# + DOM 추출
# + 기본적으로 UTF-8 인코딩 방식이지만 CP949도 지원

# %% [markdown]
# 🏷️ **웹 스크래핑(Web Scraping)과 웹 크롤링(Web Crawling)**
#
#
# ---
# + 웹 스크래핑(Web Scraping) : 웹 사이트 상에서 원하는 정보를 추출하는 기술
# + 웹 크롤링(Web Crawling) : 웹 크롤러(자동화봇)가정해진 규칙에 따라 웹 페이지를 수집해서 각 사이트의 정보를 분류하는 기술
#
#
#
#
# ---

# %% [markdown]
# ## BeautifulSoup 모듈을 활용한 스크래핑

# %% [markdown]
# ### 1. 웹 페이지 가져오기

# %%
#모듈 import 
from urllib.request import urlopen

url = 'https://news.daum.net/ranking/popular'
#웹 페이지 가져오기 
webpage = urlopen(url).read().decode('utf-8')
webpage[:200]
# Out:
# '\n<!DOCTYPE html>\n\n\n\n<html lang="ko" class="os_unknown none unknown version_0 ">\n<head>\n<meta charset="utf-8">\n<meta name="referrer" content="always" />\n\n<meta property="og:author" content="Daum 뉴스" />'

# %% [markdown]
# ### 2. BeautifulSoup 객체 생성
#
# ```python
# from bs4 import BeautifulSoup as bs
#
# 인스턴스명 = BeautifulSoup(markup, parser)
# ```
# * 첫 번째 인자 : HTML 형식의 문자열
# * 두 번째 인자 : 첫 번째 인자의 문자열을 해석하기 위한 파서
#
#   * **파서(parser) 종류**
#     + html.parser : 파이썬 표준 라이브러리에 포함된 파서로 빠르지만 유연하지 않기 때문에 단순한 HTML문서에 사용
#
#         ```
#         BeautifulSoup(markup, "html.parser")
#         ```
#
#     + lxml : 매우 빠르고 유연하지만 외부 의존
#       - lxml의 HTML 파서
#           ```
#           BeautifulSoup(markup, "lxml")
#           ```
#       - lxml의 XML 파서
#           ```
#           BeautifulSoup(markup, "lxml-xml")
#           ```
#
#     + html5lib : 웹 브라우저와 동일한 방식으로 페이지 구문 분석하는 파서로 매우 느리지만 매우 유연하지만 외부 의존
#         ```
#         BeautifulSoup(markup, "html5lib")
#       ```

# %%
#모듈 import 
from bs4 import BeautifulSoup as bs4
#DOM 문서 만들기
html = bs(webpage, 'html.parser')

# %%
type(html)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# ### 2. **Beautiful Soup 파싱 메소드**
# + 태그명
#   + **.find(태그명)** : 조건에 맞는 태그 1개만 찾음
#   + **.find_all(태그명)** : 조건에 맞는 모든 태그 찾음
# + css선택자
#   + **.select_one(선택자)** : 조건에 맞는 CSS선택자 1개만 찾음
#   + **.select(선택자)** : 조건에 맞는 CSS선택자 찾음

# %% [markdown]
# 🏷️ **HTML과 CSS**
#
#
# ---
#
#
#
# + **HTML(Hyper Text Markup Language)**
#   + 웹페이지 상에서 문단, 제목, 표, 이미지, 동영상 등을 정의하고 웹페이지 내용을 구조화하고 의미를 부여하는 마크업 언어
# + **CSS(Cascading Style Sheet)**
#   + 색상, 레이아웃 및 글꼴등 웹페이지의 디자인 요소를 담당하는 선언형 언어로 스타일 시트(Style Sheet)라고도 하고, HTML로 작성된 웹페이지를 보기 좋게 꾸며주는 스타일 규칙 언어
#
# + 참고 사이트 : <https://www.w3schools.com/>
#
#
# ---

# %% [markdown]
# #mArticle > div.rank_news > ul.list_news2 > li

# %%
#자료 추출하기
lis = html.select('#mArticle > div.rank_news > ul.list_news2 > li')
print(type(lis), ' 요소 수 : ', len(lis))
print(lis[0])
# Out:
# <class 'list'>  요소 수 :  50
# <li data-tiara-layer="news_list" data-tiara-ordnum="1" data-tiara-type="article">
# <div class="rank_num rank_popular">
# <span class="wrap_num">
# <span class="num_rank">
# <span class="num_news num1"></span>
# <span class="screen_out">1</span>
# </span>
# </span>
# </div>
# <a class="link_thumb" href="https://v.daum.net/v/20210707140504130">
# <img alt='"10원짜리 동전 80만개로 샤넬백 결제" 진상고객, 샤넬백 못산다' aria-hidden="true" class="thumb_g" src="https://img1.daumcdn.net/thumb/S95x77ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202107%2F07%2Fmoneytoday%2F20210707151822055lbuo.jpg&amp;scode=media"/>
# </a>
# <div class="cont_thumb">
# <strong class="tit_thumb">
# <a class="link_txt" href="https://v.daum.net/v/20210707140504130">"10원짜리 동전 80만개로 샤넬백 결제" 진상고객, 샤넬백 못산다</a>
# <span class="info_news">머니투데이</span>
# </strong>
# <div class="desc_thumb">
# <span class="link_txt">
#                         대한민국에서 '샤넬백 광풍'이 확산되고 백화점 줄서기 현상이 사회적 이슈로 부상하자 프랑스 명품 브랜드 샤넬(CHANEL)이 서비스 정책을 변경하면서 일부 블랙리스트 ...
#                     </span>
# </div>
# </div>
# </li>

# %%
#필요한 자료 만들기
for i in lis:
  title = i.select_one('.cont_thumb > .tit_thumb > a').text.replace('"', "")
  info_news = i.select_one(".cont_thumb > .tit_thumb > .info_news").text
  print(title, ":", info_news)
# Out:
# 10원짜리 동전 80만개로 샤넬백 결제 진상고객, 샤넬백 못산다 : 머니투데이
# 숨진채 발견된 아내..서울대 취업 기뻐했는데 눈물(종합) : 뉴시스
# [단독] 김건희 박사논문 상황 엄중..국민대, '연구윤리위' 조사 착수 : 오마이뉴스
# 새 거리두기 4단계 적용되면..퇴근 후엔 2명만·결혼식도 친족만 : 뉴스1
# 코로나19 확진 뒤 동선 숨긴 공무원에 법정 최고액 벌금형(종합) : 연합뉴스
# 총선 직전 '태영호 성폭력 의혹 고발' 시민단체 1심서 벌금형 : 뉴스1
# 코인 주식으로 돈 벌어 집 산 20대..내가 왜 취득세 폭탄? 날벼락 : 매일경제
# [현장영상] 오세훈 버스 8일부터, 지하철 9일부터 밤 10시이후 20% 감축 운행 : YTN
# [뉴시스Pic] '윤석열 전 검찰총장이 다녀간 호프집에 경찰 출동.. 무슨 일이?' : 뉴시스
# 왜 이제와서 이러냐..야간 음주단속에 뿔난 2030 : 이데일리
# 4차 대유행 직면한 '2050', 당분간 백신접종 없다 : 머니투데이
# 국민의힘 코로나 4차 대유행 현실화..정부의 무능한 방역탓 : 아시아경제
# 2명 모임만 허용..거리두기 4단계 적용 시 사실상 '봉쇄' : 서울신문
# 삼성 반도체 화려한 부활..휴대폰 접은 LG는 실적 새 역사(종합) : 연합뉴스
# '김프' 시세차익 15억..29번 해외 나가 ATM서 320억 뽑아 투자 : 연합뉴스
# '그런 질문 안돼~' 윤석열 브리핑 중 몸다툼(?) [TF사진관] : 더팩트
# 尹, 출마선언 전 호남 무소속 이용호에게 도와달라 : 뉴시스
# 하루 식비 2천원 때문에.. 남편에게 가계부 파업을 선언했다 [지구를 구하는 가계부] : 오마이뉴스
# 어찌 이럴 수가..기록적 폭우에 민물 덮친 해상 전복 양식장 : 연합뉴스
# 日언론 이재명, 대일 자세 문제많아..尹은 경제·외교 역량 미지수 : 뉴시스
# 띠지묶음 라면 첫 등장..업계 비닐 줄이기 확산될까 [제로웨이스트 실험실] : 한국일보
# '핫팬츠女 외면한 남자들' 사실과 다르다 최초 신고자의 반박 : 파이낸셜뉴스
# 전두환 '노마스크' 산책에..이재명 억장 무너진다 : 머니투데이
# 최대집 전 의사협회 회장, 대선 출마한다 : 연합뉴스
# 한국도 호주도 다 뚫렸다..아태 지역 델타변이 '초비상' : 뉴스1
# 오세훈 학원·음식점·노래방 종사자 선제검사 명령 : 연합뉴스
# 오세훈 '젊은층 우선접종' 요청에 정부 택배기사·미화원 우선 : 연합뉴스
# 동선 숨긴 코로나19 확진 공무원, 벌금 2000만원..법정 최고액 선고 : 경향신문
# 육군훈련소 한 분대 36명 모두 확진..변이바이러스 미검출(종합) : 뉴스1
# '폐지론' 질문에 울컥..여가부 차관 피해자 어디서 도움받나 : 노컷뉴스
# '김부선 변호' 강용석 이재명 점 있어..재검증 필요해 : 뉴시스
# 서울 583명 '최다감염'..직장인들 약속 모두 취소..출근 겁난다 : 뉴스1
# 저축성 연금 보험이래서 가입했는데.. 알고 보니 사망 보험이었다 : 매일경제
# 조국 김건희야말로 사모펀드 전문가..왜 다들 입닫나 : 뉴시스
# 北피살 해수부 공무원, 도박 빚 공개는 인권침해 : 머니투데이
# [핵잼 사이언스] 7만 년 전 슈퍼화산 폭발에도 초기 인류 생존..이유는? : 서울신문
# 조국 김건희씨야말로 사모펀드 전문가..尹 측 사실 호도 : 중앙일보
# [영상] 윤석열, 페북 이어 유튜브 개설..'도리도리' 사라졌다 : JTBC
# [단독]'120억 과태료 폭탄'에 백기 든 현대제철 : 머니투데이
# '김부선 변호' 강용석 이재명 셀프 신체검사 못 믿어..다시 받아야 : 머니투데이
# 캐나다 사람이 한국TV 보고 한국 문화·사자성어 '술술' : EBS
# [영상]대한민국 위해 뛰겠다, 구독이 응원..尹, 유튜브도 열었다 : 중앙일보
# 광안리 앞바다에 빨랫줄이 왠말이냐 해상케이블카 논란 지속 : 프레시안
# 잔인한 가족.. 결혼 거부한 시리아 소녀, 폭행 살해 후 영상 SNS에 : 머니투데이
# '둑 터지듯' 확진자 폭발적 증가..이러다 2000명 될라 : 뉴시스
# 암 예방에 효과적인 식품 3가지 : 헬스조선
# 이재명, '명추 연대' 선 긋자..추미애, '李 공격 모드' 태세 전환? : 데일리안
# 진중권 '쥴리'? 대재력가 딸이 그런 데 나갈 수 있나 : 뉴시스
# 더 이상 버틸 힘이 없어요..4차 대유행 우려에 골목상권 울상 : 뉴스1
# 교육부, 내일 학교·학원 방역 강화 대책 발표..2학기 전면 등교 여부도 밝힐 듯 : 뉴시스

# %% [markdown]
# ## 해결문제
# ---
# 댓글많은 뉴스를 사이트의 제목을 수집해서 AI Cloud의 무료 AI 서비스 중 텍스트 감정 분석 결과를 분석하고 결과를 파일로 저장하시오.단, 감성분석 분석(긍정,중립,부정)은 함수를 이용하여 작성하고 댓글수와 제목의 쉼표는 제거하시오.
#
# 예시)
# news.csv 내용
# ```
# 순위,제목,댓글수,언론사,감성,신뢰도
# 1,故손정민 父 "서울경찰청 정민이와 나를 미워한다",2564,데일리안,부정,0.9970703125
# 2,신고만하면 한국인? "中에 나라 파냐" 국적법 때린 반중정서,2274,중앙일보,부정,0.99755859375
# 3,'잔여 백신' 첫날 젊은층 대거 몰렸다..AZ 부정적 시선 바뀌나,1726,파이낸셜뉴스,부정,0.98974609375
# 4,'도쿄올림픽 지도서 독도 삭제' 요구에 日정부 "수용 불가",1543,연합뉴스,부정,0.9873046875
#
# ...
#
# 47,"손정민 사건 제가 책임지고"..경찰 '김창룡 청장 가짜뉴스' 내사,115,뉴스1,부정,0.9921875
# 48,로또 1등 수령자에 통장 비번 요구·5억 적금 강매한 농협,105,뉴스1,부정,0.99072265625
# 49,'도쿄올림픽 지도서 독도 삭제' 韓요구에 日정부 "수용 불가",97,중앙일보,부정,0.986328125
# 50,올림픽 취소로 日 배상금 떠안나..日언론 "IOC와 불평등 계약",93,뉴스1,부정,0.99609375
#
# ```

# %% [markdown]
# https://news.daum.net/ranking/bestreply

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup as bs
import json

# %%
def getPage(url):
  webpage = urlopen(url).read().decode('utf-8')
  return webpage

# %%
def AICloud(msg):
  url = "http://svc.saltlux.ai:31781"
  headers = {"Content-Type" : "application/json"}

  apiKey = "a190c67c-859e-4cce-b648-d7fe57e48a1f"
  {
    "key": "a190c67c-859e-4cce-b648-d7fe57e48a1f",
    "serviceId": "11987300804",
    "argument": {
        "type": "1",
        "query": "한국의 가을은 아름답습니다."
    }
}
  rqData = {
      "key" : apiKey,
      "serviceId": "11987300804",
      "argument": {
          "type": "0",
          "query": msg
      }
  }

  # 요청 객체 생성
  req = Request(url, headers=headers)

  #전달 데이터 json형태로 만들기
  jdata = json.dumps(rqData).encode('utf-8')

  #요청
  response = urlopen(req, jdata)

  #요청에 대한 응답처리
  resp = response.read().decode('utf-8')
  resp = json.loads(resp)
  label = resp['label']
  score = resp['score']

  #응답처리 반환
  return label, score

# %%
url = 'https://news.daum.net/ranking/bestreply'

wp = getPage(url)
wp
# Out:
# '\n<!DOCTYPE html>\n\n\n\n<html lang="ko" class="os_unknown none unknown version_0 ">\n<head>\n<meta charset="utf-8">\n<meta name="referrer" content="always" />\n\n<meta property="og:author" content="Daum 뉴스" />\n<meta property="og:site_name" content="다음뉴스" />\n<meta property="og:title" content="뉴스 랭킹"/>\n<meta property="og:image" content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" />\n<meta property="og:description" content="다음뉴스" />\n<meta property="og:url" content="https://news.daum.net/ranking/bestreply" />\n<link rel="shortcut icon" href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico">\n\n<title>뉴스 랭킹 | 다음뉴스</title>\n\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/2cf5440/common.css.merged.css" />\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/2cf5440/news.css.merged.css" />\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/2cf5440/calendar.css.merged.css" />\n\n<!--[if lte IE 8]>\n<script src="https://m2.daumcdn.net/svc/original/U0301/cssjs/JSON-js/fc535e9cc8/json2.min.js"></script>\n<![endif]-->\n<!--[if lt IE 9]>\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/2cf5440/ie8.css.merged.css" />\n<![endif]-->\n\n<script src="//t1.daumcdn.net/media/kraken/news/2cf5440/common.merged.js"></script>\n\n<script type="text/javascript" src="https://t1.daumcdn.net/tiara/js/v1/tiara.min.js"></script>\n\n<script>\n  var ENV = {\n    Profile: {\n      isProduction: \'true\' || false,\n      isSandbox: \'\' || false,\n      isCbt: \'\' || false,\n    }\n  }\n</script>\n        <script src="//t1.daumcdn.net/media/kraken/news/2cf5440/rankingMain.merged.js"></script>\n</head>\n<body class="bg_news">\n<div id="kakaoIndex">\n    <a href="#kakaoBody">본문 바로가기</a>\n    <a href="#kakaoGnb">메뉴 바로가기</a>\n</div>\n\n<div id="kakaoWrap" class="news_type1">\n<div id="wrapMinidaum"></div>\n<script type="text/javascript">\n\tvar minidaum_options = {\n\t\tbgType\t\t\t\t: "white",\n\t\tenableLogoutRetun\t: true,\n\t\tdisableTracker\t\t: true, // false일 경우 사용, true일 경우 미사용\n\t\tenableShield\t\t: false\n\t};\n</script>\n<script src="https://go.daum.net/minidaum_pc.daum"></script>\n\n<div id="kakaoHead" role="banner">\n\t<div class="head_media">\n\t\t<h1>\n\t\t\t<a href="https://news.daum.net/" id="kakaoServiceLogo" data-tiara-layer="GNB default service_news"><span class="ir_wa">뉴스</span></a>\n\t\t</h1>\n\t\t<strong class="screen_out">관련서비스</strong>\n\t\t<ul id="kakaoRelServices" data-tiara-layer="GNB default">\n\t\t\t<li><a href="https://entertain.daum.net" class="link_services link_services1" data-tiara-layer="service_enter"><span class="ir_wa">연예</span></a></li>\n\t\t\t<li><a href="https://sports.daum.net" class="link_services link_services2" data-tiara-layer="service_sports"><span class="ir_wa">스포츠</span></a></li>\n\t\t</ul>\n<h2 class="screen_out">검색</h2>\n<div class="search_news" id="search_news">\n\t<form id="kakaoSearch" name="kakaoSearch" action="//search.daum.net/search" method="get">\n\t\t<fieldset class="fld_inside">\n\t\t\t<legend class="screen_out">검색어 입력폼</legend>\n\t\t\t<div class="box_searchbar">\n\t\t\t\t<label for="qVal" class="lab_search">통합검색</label>\n\t\t\t\t<input type="hidden" name="DA" value="23A" />\n\t\t\t\t<input type="hidden" name="rtmaxcoll" value="NNS">\n\t\t\t\t<input type="text" class="tf_keyword" id="qVal" name="q" value="" title="검색어 입력" autocomplete="off" spellcheck="false">\n\t\t\t\t<button id="kakaoBtnSearch" class="btn_search" type="submit"><span class="ir_wa">검색</span></button>\n\t\t\t</div>\n\t\t</fieldset>\n\t\t<div id="wrap_suggestBox" class="wrap_suggestBox">\n\t\t\t<div id="suggestBox" class="suggestBox box_sub">\n\t\t\t\t<div class="baseBox bg" style="display: none"></div>\n\t\t\t</div>\n\t\t</div>\n\t</form>\n</div>\n<script type="text/javascript" src="https://search1.daumcdn.net/search/suggest_pc/ ...

# %%
html = bs(wp, 'html.parser')

# %%
lis = html.select('#mArticle > div.rank_news > ul.list_news2 > li')
lis[0]
# Out:
# <li data-tiara-layer="news_list" data-tiara-ordnum="1" data-tiara-type="article">
# <div class="rank_num ">
# <span class="wrap_num">
# <span class="num_rank">
# <span class="num_news num1"></span>
# <span class="screen_out">1</span>
# </span>
# </span>
# <span class="info_rank">
# <span class="screen_out">댓글수</span>
# <span class="ico_news2">8,264</span>
# </span>
# </div>
# <a class="link_thumb" href="https://news.v.daum.net/v/20210707093410967">
# <img alt="진중권 &quot;'쥴리'? 대재력가 딸이 그런 데 나갈 수 있나&quot;" aria-hidden="true" class="thumb_g" src="https://img1.daumcdn.net/thumb/S95x77ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202107%2F07%2Fnewsis%2F20210707093410981qfnl.jpg&amp;scode=media"/>
# </a>
# <div class="cont_thumb">
# <strong class="tit_thumb">
# <a class="link_txt" href="https://news.v.daum.net/v/20210707093410967">진중권 "'쥴리'? 대재력가 딸이 그런 데 나갈 수 있나"</a>
# <span class="info_news">뉴시스</span>
# </strong>
# <div class="desc_thumb">
# <span class="link_txt">
#                         [서울=뉴시스]최서진 기자 = 진중권 전 동양대 교수는 7일 윤석열 전 검찰총장의 부인 김건희씨의 '쥴리' 논란에 대해 "대재력가 어머니의 딸이 그런 데 나간다는 것 자...
#                     </span>
# </div>
# </div>
# </li>

# %%
lis[0].select_one('.screen_out').text
# Out:
# '1'

# %%
lis[0].select_one('.ico_news2').text.replace(',','')
# Out:
# '8264'

# %%
lis[0].select_one('.info_news').text
# Out:
# '뉴시스'

# %%
with open('/content/news.csv', 'w') as fp:
  linehead = '순위,제목,댓글수,언론사,감성,신뢰도\n'
  fp.write(linehead)
  for li in lis:
    rank = li.select_one('.screen_out').text
    title = li.select_one('.tit_thumb > a').text.replace(',','')
    cnt = li.select_one('.ico_news2').text.replace(',','')
    news = li.select_one('.info_news').text
    aicloud = AICloud(title)
    #aicloud = ('부정', '0.9')
    line = f'{rank},{title},{cnt},{news},{aicloud[0]},{aicloud[1]}\n'

    print(line)
    fp.write(line)
# Out:
# 1,진중권 "'쥴리'? 대재력가 딸이 그런 데 나갈 수 있나",8264,뉴시스,부정,0.99609375
#
# 2,'김부선 변호' 강용석 "이재명 점 있어..재검증 필요해",8017,뉴시스,부정,0.9169921875
#
# 3,[단독] "김건희 박사논문 상황 엄중"..국민대 '연구윤리위' 조사 착수,6677,오마이뉴스,부정,0.98486328125
#
# 4,국민의힘 "코로나 4차 대유행 현실화..정부의 무능한 방역탓",5478,아시아경제,부정,0.99609375
#
# 5,최대집 전 의사협회 회장 대선 출마한다,4826,연합뉴스,중립,0.84619140625
#
# 6,[현장영상] 오세훈 "버스 8일부터 지하철 9일부터 밤 10시이후 20% 감축 운행",3260,YTN,중립,0.935546875
#
# 7,"왜 이제와서 이러냐"..야간 음주단속에 뿔난 2030,2966,이데일리,부정,0.99755859375
#
# 8,'폐지론' 질문에 울컥..여가부 차관 "피해자 어디서 도움받나",2850,노컷뉴스,부정,0.98583984375
#
# 9,[영상] 윤석열 페북 이어 유튜브 개설..'도리도리' 사라졌다,2744,JTBC,부정,0.994140625
#
# 10,"10원짜리 동전 80만개로 샤넬백 결제" 진상고객 샤넬백 못산다,2350,머니투데이,부정,0.9609375
#
# 11,코인 주식으로 돈 벌어 집 산 20대.."내가 왜 취득세 폭탄?" 날벼락,1835,매일경제,부정,0.99658203125
#
# 12,日언론 "이재명 대일 자세 문제많아..尹은 경제·외교 역량 미지수",1587,뉴시스,부정,0.99609375
#
# 13,[영상]"대한민국 위해 뛰겠다 구독이 응원"..尹 유튜브도 열었다,1537,중앙일보,긍정,0.94873046875
#
# 14,조은희 "4차 대유행 주범 20~30대 아닌 문재인 정부",1441,뉴스1,부정,0.9912109375
#
# 15,'그런 질문 안돼~' 윤석열 브리핑 중 몸다툼(?) [TF사진관],1120,더팩트,부정,0.81591796875
#
# 16,조국 "김건희야말로 사모펀드 전문가..왜 다들 입닫나",1045,뉴시스,부정,0.99609375
#
# 17,오세훈 시장의 호소 "코로나 최대 위기 인내 결집해야 할 때",996,머니투데이,부정,0.97021484375
#
# 18,보행자 치어 숨지게 하고는 "재수가 없어" 큰소리친 50대,963,연합뉴스,부정,0.9970703125
#
# 19,[오차범위]이재명·윤석열 1위 굳건..스캔들·쥴리 논란에도 강세 이유는,903,뉴스1,부정,0.90283203125
#
# 20,4차 대유행 직면한 '2050' 당분간 백신접종 없다,724,머니투데이,부정,0.98828125
#
# 21,'바지 발언' 쏘아 올린 이재명..김부선 "이잘알 변호사 내편 바지 벗을 시간",698,더팩트,부정,0.99365234375
#
# 22,'1인 최대 500만원' 내일배움카드 공무원·대기업 직원도 가능,649,연합뉴스,중립,0.86083984375
#
# 23,[단독] "쿠팡 실태 폭로한다"던 배송기사 알고 보니 민주당 청년위원,641,조선일보,부정,0.96142578125
#
# 24,강남 발칵 뒤집혔다..현대백화점 확진 수백미터 검사 대기줄[영상],596,중앙일보,부정,0.9921875
#
# 25,무면허로 사람 치어 숨지게 하고 "재수가 없었다"..징역 3년,463,이데일리,부정,0.99658203125
#
# 26,육군훈련소 한 분대 36명 모두 확진.."변이바이러스 미검출"(종합),442,뉴스1,부정,0.80419921875
#
# 27,조국 "사모펀드 윤로남불..유인태 왜 윤석열 아내 비판 안 하나",436,한국일보,부정,0.9970703125
#
# 28,"서울대 청소노동자에 '관악학생생활관' 영어로 써 보라 갑질",433,YTN,부정,0.9970703125
#
# 29,이홍구 "이재명 美점령군 발언 정치적 의도 아닌 무지해서 한 말",404,조선일보,부정,0.99658203125
#
# 30,현대百 방문자 수만명 검사받아야..정부 "거리두기 4단계 격상 검토",401,한국경제,부정,0.8828125
#
# 31,수도권 990명 이대로라면 수도권 4단계도 가능,328,이데일리,중립,0.82421875
#
# 32,검찰 윤석열 아내 수사 1년째 '만지작'..배경은?,292,한겨레,부정,0.9091796875
#
# 33,가짜 수산업자 주장에..탁현민이 소개한 '진짜 대통령 선물' 감별법,279,한국일보,부정,0.7470703125
#
# 34,"정부가 똥볼을 차놓고 국민 협박" 조은희 서초구청장 작심비판,273,경향신문,부정,0.9970703125
#
# 35,與 "이대남 분노 이용하나"..유승민 '여가부 폐지' 맹비난(종합),248,뉴시스,부정,0.9970703125
#
# 36,조광한 "남양주 직원 道 조사관에 '옷만 벗기지 말아달라'고 했다",245,뉴스1,부정,0.83935546875
#
# 37,[단독] 윤석열과 고급 주상복합..이상한 전입신고,210,시사저널,부정,0.84765625
#
# 38,이낙연 후원금 15억 육박.."눈물 날 정도로 고맙다" 감사 인사,191,뉴스1,긍정,0.9921875
#
# 39,'여가부 폐지론' 후폭풍.."여가부 없으면 피해자 어디서 도움 받나" 발끈,183,뉴시스,부정,0.9970703125
#
# 40,이재명 알고 보면 섬세한 남자?..與 8룡 중 유일한 MBTI 'I유형',181,뉴스1,부정,0.484375
#
# 41,자영업자들 "방역 실패한 정부 왜 우리만 옥죄나",178,매일경제,부정,0.99755859375
#
# 42,[영상] 떨리는 목소리로 "최선 다해"..김 차관 '여가부 폐지'는 별개,172,연합뉴스,부정,0.9814453125
#
# 43,재난지원금 소득 하위 80%→전국민 변경되나..민주당 '보편지원' 무게,155,경향신문,부정,0.990234375
#
# 44,지지모임 띄운 원희룡 "제겐 흠이 없다"..김종인 "대통령 자질 갖춰",155,국민일보,부정,0.6240234375
#
# 45,'네덜란드 유명기자 피습'에 文 "지금 겪고 있는 충격에 위로",139,뉴스1,부정,0.94580078125
#
# 46,국민대 윤석열 부인 박사논문 의혹 조사 착수,135,이데일리,부정,0.82177734375
#
# 47,[단독] '조국 수사때 대검 차장' 강남일 연구위원 사의 표명,133,조선일보,부정,0.83642578125
#
# 48,이준석 '패싱'한 尹 안철수와 정치 상담..몸값 높이기?,109,뉴시스,부정,0.9970703125
#
# 49,수지·제니 얼굴 베끼려다..대박 터진 '로지' 탄생 뒷얘기 [영상],95,중앙일보,부정,0.56201171875
#
# 50,[ET] "아가야 엄마 일터란다" 국회 온 생후 '59일 아기',95,KBS,중립,0.55859375

# %% [markdown]
# ---
#
#
# ※ 카카오톡 메신저 내용 분석해보기
#
#
# ---
