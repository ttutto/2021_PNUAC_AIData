# %% [markdown]
# <a href="https://colab.research.google.com/github/ttutto/2021_PNUAC_AIData/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
age_x = [i for i in range(25, 36)]
dev_y =   [38496, 42000, 46752, 49320, 53200,
           56000, 62316, 64928, 67317, 68748, 73752]

py_dev_y = [45372, 48876, 53850, 57287, 63016,
            65998, 70003, 70000, 71496, 75370, 83640]

# %%
plt.plot(age_x, dev_y, 'k.--', label = 'All Devs')

plt.plot(age_x, py_dev_y, 'bo-', linewidth = 3, label = 'Python')

plt.xlabel('Age')
plt.ylabel('Median Salary(USD)')
plt.title('Median Salary (USD) by Age')

plt.legend()

plt.show()
